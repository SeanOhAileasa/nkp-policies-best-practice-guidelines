# %% [markdown]
# ***
# < [Home](https://github.com/SeanOhAileasa) | [README](https://github.com/SeanOhAileasa/nkp-policies-best-practice-guidelines/blob/main/README.md) >
#
# ## CompTIA Network+ - Course Material 2022
# ### Topic: ``Policies and Best Practice Guidelines``
# ***

# %% [markdown]
# Course material for the ``CompTIA Network+`` module of the ``ICT Associate Apprenticeship (Cybersecurity)`` programme.

# %% [markdown]
# <a id="top"></a>
# ***
# ## Table of Contents
# ***

# %% [markdown]
# ###### Quick Links
# ***
#
# * [Policies and Best Practice Guidelines](#policiesandBestPracticeGuidelinestop)&nbsp;&nbsp;|&nbsp;&nbsp;[Test](#toppoliciesandBestPracticeGuidelinesTest)

# %% [markdown]
# <hr width=50%;>

# %% [markdown]
# <a id="policiesandBestPracticeGuidelinestop"></a>
# ### [Policies and Best Practice Guidelines](#policiesandBestPracticeGuidelines)
#
# - [1. Course Introduction](#policiesandBestPracticeGuidelines1CourseIntroduction) <br/><br/>
# - [2. Privileged User Agreement](#policiesandBestPracticeGuidelines2PrivilegedUserAgreement) <br/><br/>
# - [3. Password Policy](#policiesandBestPracticeGuidelines3PasswordPolicy) <br/><br/>
# - [4. Onboarding and Offboarding](#policiesandBestPracticeGuidelines4OnboardingandOffboarding) <br/><br/>
# - [5. Licensing Restrictions](#policiesandBestPracticeGuidelines5LicensingRestrictions) <br/><br/>
# - [6. International Export Controls](#policiesandBestPracticeGuidelines6InternationalExportControls) <br/><br/>
# - [7. Data Loss Prevention](#policiesandBestPracticeGuidelines7DataLossPrevention) <br/><br/>
# - [8. Remote Access Policies](#policiesandBestPracticeGuidelines8RemoteAccessPolicies) <br/><br/>
# - [9. Incident Response Policies](#policiesandBestPracticeGuidelines9IncidentResponsePolicies) <br/><br/>
# - [10. BYOD, AUP, and NDA](#policiesandBestPracticeGuidelines10BYODAUPandNDA) <br/><br/>
# - [11. System Life Cycle](#policiesandBestPracticeGuidelines11SystemLifeCycle) <br/><br/>
# - [12. Safety Procedures and Policies](#policiesandBestPracticeGuidelines12SafetyProceduresandPolicies)

# %% [markdown]
# ### [Practice: Incorporate Best Practice Guidelines](#policiesandBestPracticeGuidelinespractice)
#
# * [1. Exercise: Incorporate Best Practice Guidelines](#policiesandBestPracticeGuidelinesexercise)

# %% [markdown]
# <a id="toppoliciesandBestPracticeGuidelinesTest"></a>
# ### ⚡ [Test](#policiesandBestPracticeGuidelinesTest)

# %% [markdown]
# <hr width=50%;>

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="policiesandBestPracticeGuidelines"></a>
# ***
# ### Policies and Best Practice Guidelines
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="policiesandBestPracticeGuidelines1CourseIntroduction"></a>
# ***
# ###### 1. Course Introduction
# ***

# %% [markdown]
# Cover the guidelines that ensure optimal network performances security including password policies, data loss prevention techniques, non-disclosure agreements and safety procedures and policies.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="policiesandBestPracticeGuidelines2PrivilegedUserAgreement"></a>
# ***
# ###### 2. Privileged User Agreement
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``identify privileged user agreements``

# %% [markdown]
# In this presentation, we'll take a look at the Privileged User Agreement, which is typically a document that defines what privileged access means.

# %% [markdown]
# And in almost every computing environment, there is at least one user who has elevated powers within a specific computer system or for the entire network.

# %% [markdown]
# And that quite simply means they have greater power than a regular system user, they can do things that standard users cannot do.

# %% [markdown]
# So the privileged users may have access to systems that can affect those individual computing systems or overall network communication, the user accounts that are in use and, of course, the files and folders.

# %% [markdown]
# So, quite simply, they oversee the day-to-day operations of the IT environment.

# %% [markdown]
# So then privileged access is typically granted to system administrators or networks administrators, and you might hear of those two terms used fairly interchangeably. But, I guess, at the most official levels, system administrators are responsible for specific systems, such as messaging servers or database servers.

# %% [markdown]
# Whereas network administrators would be more so concerned with the routers, the switches, the utilization of bandwidth, firewalls, the security, demilitarized zones, things along those lines. But, again, in day-to-day conversation you'll hear those two terms used fairly interchangeably.

# %% [markdown]
# But you might also see select staff that are required to perform special duties over a computing system or a network that might be dedicated to specific departments. For example, there could be an IT person specifically for accounting or human resources. Or, again, there might just be a dedicated system within the organization, such as a healthcare system. So you might have specific people that have some elevated capabilities within those departments or for those systems.

# %% [markdown]
# As for the expectations, users with privileged access must respect the rights of the system users, the integrity of the system itself, and any peripheral or related physical resources. And, of course, they also have to comply with policies of the organization, laws, and any other regulations that might be imposed by any kind of commission or just the business itself.

# %% [markdown]
# Other considerations, the user who has the privileged access has to be authorized. In other words, whoever it is going to be, they typically have to sign a Privileged User Agreement. And in some cases, they might even need to be security cleared, particularly in the military, for example, there are various levels of security clearance.

# %% [markdown]
# And the job duties, effectively, should be minimized when it comes to the privileged access, meaning that you should only use those privileges when they are necessary to perform the required task. Or, you look at from the other perspective, if any particular duty can be performed in another manner, then avoid using the privileged access. So if, for example, you are just logging on to your workstation to check your email, you should not log on as an administrator. You should create a separate account for yourself that is just a regular user, and for your standard day-to-day tasks you should log in as the regular user. Then when you need to perform those elevated tasks, then certainly log in as the administrator or invoke the administrative credentials. But, generally, it means, do not log in as an administrator all the time, every day. Because if your account should be compromised, for example, you just go up to get a coffee and you leave your system logged in, then anyone else could sit down at that station and perform tasks as an administrator. Also, if any kind of malware should find its way onto your system and you are logged in as an administrator, then the malware typically runs as an administrator as well. So again, whenever possible, log in as a regular user.

# %% [markdown]
# Some other considerations, with respect to the duties that are generally involved with those elevated capabilities, include running security software, monitoring systems for reliability and security, installing system software. Moving or archiving files and folders, certainly, implementing repairs, fixing files or file processes, stopping or starting services. Killing processes that seem to be consuming too many resources, what they refer to often as runaway processes, or those that might seem to be invasive or intrusive processes.

# %% [markdown]
# And when it comes to some of those duties, again, it often involves the ability to grant, change, or deny access to any given resource to other users. So, of course, you are in charge of saying you may access this, you can't access this and/or, of course, making changes. You might also be able to grant your privileges, or at least a certain level of elevated privileges, to other people. So it might be at your discretion to say, okay, this person is going to be promoted, if you will, to a junior administrator. Therefore, I am going to grant them the following privileges. And you would ultimately be responsible then for whatever that person does because you gave them the ability to do so.

# %% [markdown]
# Some other examples might include disabling an account that was abusing a system, such as sending harassing emails, or, of course, blocking network intrusion attempts.

# %% [markdown]
# But there can be a lot of responsibility that falls on you as the privileged user, so you have to be willing to undertake those responsibilities and, of course, willing to face the consequences in the event that something does go wrong.

# %% [markdown]
# So again, it's just something that should be clearly outlined with respect to what the responsibilities are.

# %% [markdown]
# And, of course, it's something that should be known very well by both sides, you as the privileged user and the powers that be, if you will, so that everybody understands what is expected.

# %% [markdown]
# And sometimes that involves you, as the administrator, informing them that this should not be done this way or this should be changed. Because sometimes, you might have a higher level of technical knowledge than those who are hiring you. And that's fine, but as long as everybody understands how things should be implemented, then these are the things that you want to include and are outlined in the Privileged User Agreement.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="policiesandBestPracticeGuidelines3PasswordPolicy"></a>
# ***
# ###### 3. Password Policy
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``recognize appropriate password policies``

# %% [markdown]
# In this demonstration, we will take a look at implementing a password policy, which is something that is familiar to most users.

# %% [markdown]
# You would almost always find some kind of password policy in every computing environment.

# %% [markdown]
# And it deals with how the users have to manage their passwords. For example, being required to change it from time to time. [The Server Manager window appears. It contains two panes, navigation pane and content pane. The navigation pane includes options such as Dashboard, AD DS, and DNS. The content pane contains two sections, WELCOME TO SERVER MANAGER and ROLES AND SERVER GROUPS. The WELCOME TO SERVER MANAGER further includes links such as Add roles and features and Create a server group. ] And then when they do change it some of the restrictions that are in place to ensure that the password is as secure as possible.

# %% [markdown]
# Now, for this demonstration I'm using a Windows and Active Directory environment. So, of course, this would not be applicable to a Unix or a Linux environment but the considerations are virtually the same in almost any type of configuration.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# So, this particular server is what's known as a domain controller in Active Directory, and it handles all of the security settings, among many other things. But, you can find this option on the domain controller by going to your server manager that you see here, and then clicking on Tools, [from the menu. A shortcut menu appears. ] and choosing Group Policy Management.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Now I've already launched that to save a bit of time, so let's just minimize Server Manager. And here is the Group Policy Management console.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# [He opens Group Policy Management window. It contains two panes, navigation pane and content pane. The navigation pane includes Group Policy Management node and various subnodes under it such as Zoflina.com, Group Policy Objects, WMI filters, Default Domain Policy. ] And in here, you can expand your domain [He clicks the Zoflina.com subnode. Its contents get displayed in the content pane. ] and then you can expand group policy containers. [He clicks the Group Policy Objects subnode. Its contents get displayed in the content pane.] And you will find the Default Domain Policy, [He clicks the Default Domain Policy subnode. Its contents get displayed in the content pane. ] this is where you can find the password policy. So that's a sub-component of the overall domain policy, if you will.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# So you can just right-click the policyand choose Edit, and that brings up your editor.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# And again, I've already launched that, [He minimizes the Group Policy Management window. ] and here is the editor itself. [He opens Group Policy Management Editor window. It contains two panes, navigation pane and content pane. The navigation pane includes Default Domain Policy node and various subnodes under it such as Computer Configuration, Policies, Windows Settings, Security Settings, Account Policies, and Password Policy. ] So within the editor, you can expand computer configuration, policies, Windows settings, security settings, account policies, and there is the password policy. [The Policy options of Password Policy gets displayed in the content pane. There is a Policy Setting corresponding to every Policy. ]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# So these are the configurable values for a password policy and they apply to everyone in the entire domain. [He points at the Policy options. ]

# %% [markdown]
# Now again, this might vary a little bit, depending on the operating system and, or the environment you are using. But again, most of these considerations are consistent.

# %% [markdown]
# So the first one we see here [under Policy options. ] is to enforce password history, which effectively means that when you are forced to change your password, you cannot change it to the same password you were just using. Sometimes people of course like their password and they don't want to change it. So, if it did not remember any passwords, [He points at the Policy Setting corresponding to the Enforce password history. ] and your password was, let's just say, hello, then you could go through the motions of changing it. But you could change it right back to hello, and that would be accepted again if zero passwords were remembered. So by remembering, in this case 24, and I should mention by the way that these are all the default settings, I haven't changed any of these, then it means that you must cycle through 24 different passwords before you can go back to hello again.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The maximum password age is the expiry time and the default is 42 days which is six weeks. [He points at the Policy Setting corresponding to the Maximum password age Policy. ] You can set this to whatever you want, but at the end of this period, you must change your password.

# %% [markdown]
# The minimum password age is how long you must use a new password for before you can voluntarily change it. Sometimes, you might decide, well, I don't like that password, it's too easy to guess, so I'd like to change it fairly quickly. So one day means you must use it for at least a day then you can change it voluntarily. [He points at the Policy Setting corresponding to the Minimum password age Policy. ]

# %% [markdown]
# The password length is the number of characters. [He points at the Policy Setting corresponding to the Minimum password length Policy. ] Now this of course is up to you. And in terms of the length, longer passwords are certainly considered to be more secure because they're harder to guess. But if you go too far with this, then it can become very difficult for users to remember what the password is. And it can kind of backfire because they, of course, end up writing it down on a sticky note on the monitor, or under the mouse pad or under the keyboard, things along those lines. So a happy medium there can be a little bit difficult to find sometimes.

# %% [markdown]
# Password must meet complexity requirements does actually involve the length but a combination of some other considerations. And in fact you can just double click on any one of these [He clicks the Password must meet complexity requirements Policy and the Password must meet complexity requirements Properties dialog box opens. ] and there is an Explain tab that tells you what this is all about. [He clicks the Explain tab. ] So you can see to meet overall complexity requirements it tells you right here. [He highlights the contents of Explain tab. ]

# %% [markdown]
#  So it cannot contain the user's account name or parts of it, so you can't use your own name, basically. And in fact, a part of your name cannot even consist of two consecutive characters, so any part of your name appearing in the password is unacceptable. It has to be at least six characters in length. Now that is likely going to vary depending on the operating system, but that's the minimum to meet complexity. And then you can see that it has to contain three of the four following categories, uppercase characters, lowercase characters, digits, and all non alphabetic characters. So as long as you meet three of those four, plus these other ones, then you have met the overall complexity requirements. [He clicks the Cancel button and the dialog box closes. ] So again this is where you might try to change it to something, and you don't meet one of those requirements, it will tell you. You don't meet the requirements, try again.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# And storing passwords using reversible encryption, [He points at the Store passwords using reversible encryption Policy. ] you might not find this in other environments, and this is generally not recommended. But in some cases you might have some fairly old applications that require the password actually be passed in, essentially in plain text, it would allow the operating system to decrypt the password to present it to any kind of application or service. Again, that's usually for only fairly old applications. These days I can't imagine you would need this on. But if you do encounter any kind of issues when it comes to authentication in combination with this application you can enable that feature. But strongly recommended to not enable reversible encryption. And again you can double-click [The Store passwords using reversible encryption Properties dialog box opens. ] and there is an Explain tab right there [He clicks the Explain tab. ] that tells you what this is all about. [In the content pane. ]

# %% [markdown]
# So again generally leave this disabled. [He clicks the Cancel button and the dialog box closes. ] So for Windows environments, again these are all, default values but you can just double-click [He double-clicks the Maximum password age Policy. The Maximum password age Properties dialog box opens. It includes Security Policy Setting tab. ] on any one of them and you can change it to whatever you want. [He points at the spin box under Security Policy Setting tab that contains the number of days within which the password will expire. ] So 30 days is fairly common, maybe 60 days and that really is up to you. [He clicks the OK button and the dialog box closes. ]

# %% [markdown]
# Generally, higher security environments tend to have shorter expiration times. Again, the idea being that the longer you have a password, the more time you give an intruder to figure out what it is or you might simply tell someone else. If it's someone that you do trust you might say well here use my password. That might spread its way around fairly easily, so again the shorter amount of time you use that password the less time you allow for anyone else to find out what it is. So again, all of those values are up to you. But you do have to try to figure out something that meets the requirements while still is not so complex or so difficult that users end up writing all their passwords down, which, of course, defeats the purpose entirely. But those are some of the common considerations when it comes to a password policy.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="policiesandBestPracticeGuidelines4OnboardingandOffboarding"></a>
# ***
# ###### 4. Onboarding and Offboarding
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``describe onboarding and offboarding techniques``

# %% [markdown]
# In this presentation, we'll take a look at the onboarding and offboarding processes, beginning with onboarding.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Onboarding
# ***

# %% [markdown]
# [Onboarding. ] Which refers to assisting new employees to adapt to a new job or responsibility, or a new organizational culture.

# %% [markdown]
# And the goals are quite simply to engage and connect immediately with new hires to reduce employee turnover.

# %% [markdown]
# And to increase productivity and success by making the new hires feel as comfortable as possible, as quickly as possible.

# %% [markdown]
# Some best practices with respect to the process. It certainly helps to develop a plan and standards, and involve the stakeholders at all levels in the process so that everyone has a say. And the expectations and responsibilities should be clearly explained so that the new hire understands what is expected and what they are responsible for.

# %% [markdown]
# And it should highlight any opportunities for any new hires to participate in the process, and outline technology rules and regulations that are in place.

# %% [markdown]
# And it's something [such as program. ] that should always be implemented consistently. In other words, you should not have some people coming in that are going through the entire process while others come in and don't experience the process at all.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### IT Onboarding Checklist
# ***

# %% [markdown]
# [IT Onboarding Checklist. ] Now when it comes to IT onboarding, you might want to involve some sort of checklist, which can be developed to prepare your IT related services for the new hire.

# %% [markdown]
# And this ensures that they will be equipped and productive as soon as possible.

# %% [markdown]
# Now, the checklist, of course, may vary depending on what the job function and/or the location is. But it can help to serve as a guide for new employees as to what services are available in the organization. What do we have? And how should you go about availing yourself of these services?

# %% [markdown]
# A sample checklist might include creating an Active Directory account in a Windows environment which includes the user name and the password.

# %% [markdown]
# Defining access to network shares.

# %% [markdown]
# Setting up an e-mail account. [or e-mail access. ]

# %% [markdown]
# Setting up VPN access if the user is going to travel or work from home at all.

# %% [markdown]
# Setting up a standard telephone service. [Setting up ]

# %% [markdown]
# Orientation, of course, just getting familiar with the overall environment.

# %% [markdown]
# And possibly providing database access.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Offboarding
# ***

# %% [markdown]
# [Offboarding. ] Now offboarding is, as you might imagine, effectively the exact opposite.

# %% [markdown]
# A strategic process for transitioning or removing an employee from an organization, and this is equally as important as onboarding.

# %% [markdown]
# So again, a checklist can be developed to ensure general tasks are completed prior to the employee leaving.

# %% [markdown]
# And offboarding can help to ensure that an employee departs the organization on good terms regardless of the situation.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### IT Offboarding Checklist
# ***

# %% [markdown]
# [IT Offboarding Checklist. ] So again this is something that should be taken care of as soon as possible.

# %% [markdown]
# And the tasks might involve essentially doing the opposite of what you did with the onboarding checklist.

# %% [markdown]
# So we would disable their Active Directory account.

# %% [markdown]
# We might reset their email passwords and/or disable those accounts. Sometimes the email accounts are different than their general user accounts.

# %% [markdown]
# And maybe you might set up mail forwarding. If, for example, someone else is going to look after that position even just temporarily. And some other customers or people outside of the organization are still sending emails to that person who is gone. Then they can be forwarded off to someone else to handle.

# %% [markdown]
# Of course remove the telephone system and remove the voicemail, and certainly remove user access to the databases.

# %% [markdown]
# Now you generally don't have to concern yourself with things like removing permissions from any given resource because once their account has been disabled, it can no longer be used to access those resources. So, it's actually recommended to leave most of them in place in anticipation of someone else coming in to assume that same position.

# %% [markdown]
# And if that's the case, then you can just re-enable the account, rename it, of course, but all of the permissions are still in place.

# %% [markdown]
# So this way, you don't have to go through the entire process of setting everything up again.

# %% [markdown]
# So, in most environments, in fact, it is very common to just see their accounts disabled as opposed to deleted. Because again, simply the same job might go to someone else.

# %% [markdown]
# Now, if you are certain the position itself is being removed, then you might want to consider deleting the account entirely. But disabling is just as effective in terms of keeping them out.

# %% [markdown]
# So, ultimately it is up to you to define what is involved with both onboarding and offboarding. But the more clearly everything can be defined, the easier these types of transitions will be.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="policiesandBestPracticeGuidelines5LicensingRestrictions"></a>
# ***
# ###### 5. Licensing Restrictions
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``recognize appropriate licensing restrictions``

# %% [markdown]
# As an administrator of an IT environment it typically falls upon you to be mindful of how software is implemented in the environment.

# %% [markdown]
# So as such, in this presentation we'll take a look at the software license.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Software Licence
# ***

# %% [markdown]
# [Software License. ] Now this is a document providing legally binding guidelines that outline the use and the distribution of software.

# %% [markdown]
# And licensing provides organizations with this documentation to use one or more copies of the software while ensuring that no copyrights are violated.

# %% [markdown]
# It also defines responsibilities of parties purchasing the software product and outlines any restrictions on how it can be used.

# %% [markdown]
# Now for the most part those restrictions deal with redistributing the software. You are not allowed to take someone else's product, repackage it and sell it for your own gain.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Software Licensing Terms
# ***

# %% [markdown]
# [Software Licensing Terms. ] Now most licensing agreements will include terms of the license, including statements such as a fair use. [of software. ] And this refers to, quite literally, how it is intended to be used and what is its purpose.

# %% [markdown]
# Now something that you might need to consider here is what's known as reverse engineering. [the software. ] That in and of itself is perfectly legal. And it basically means that anyone can create a software application for a particular purpose. And they can design it however they see fit. You are then allowed to also design software for the same purpose. But of course you are not allowed to use the exact same methods as those that have already been implemented by the software application that you've already obtained. So again, the idea is to do the same thing, but in a different manner. That's effectively reverse engineering. I mean, you can come up with anything you want for any purpose. But it has to be done differently than one that is already in place. So that should be outlined in a licensing term.

# %% [markdown]
# You might also see limitations of liability. For example, any kind of breach of contract and what kind of damages might result in that.

# %% [markdown]
# And of course warranties, disclaimers, and protections. For instance, if the software use infringes on the intellectual property or the rights of any users.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Types of Software Licenses
# ***

# %% [markdown]
# [Types of Software Licenses. ] Now in terms of the types of software licenses, there are a few different categories.

# %% [markdown]
# The first being proprietary, which means that the product is copyrighted which bears limits against its use, its distribution, and modification. And it remains the property of the software owner or the creator. So organizations acquire and use the software under predefined conditions imposed by the owner. In other words, they license a copy. And once you obtain it you are of course allowed to use it for the purpose that was intended by the developer. And this is primarily what you see in most corporate environments most of the time.

# %% [markdown]
# But there is also, of course, free software. And this is any kind of application that can be freely acquired, used, modified, and even redistributed. But the only restriction is that redistribution of the software must follow the original terms. For example, again, you are not allowed to take free software, repackage it and then sell it for personal gain. It has to effectively remain as free software.

# %% [markdown]
# And finally, open source, which is similar to free software in that the source code of a program is made available to the public free of charge. And the source code can be used or modified as per the needs of the developer who is actually implementing it. But whereas free software is typically just created by a single entity or a single person, open source code is often developed as part of a public collaboration. There is a community, if you will, wherein everybody can have a say. But the model itself is that the software must be redistributed without any restrictions. The source code must remain freely available. And improved versions of the software can carry a different name if outlined and documented in the licensing. So there are a few more restrictions or controls, if you will, on open source software, but it is still free. That's certainly attractive to a lot of organizations. If you can find an open source application that suits your needs, then clearly you can save some money. But one of the drawbacks with both free software and open source is that there really is no support. The vendor does not provide any kind of support. In a lot of cases, there really is no specific vendor. It's not being sold. So you can certainly find a lot of documentation and a lot of forums on the Internet that can help you out. But when you purchase proprietary software the license also typically defines what kind of support is available.

# %% [markdown]
# So ultimately it's your decision, but there are certainly pros and cons of both. So I would put a little bit of extra research into any given type of application before you actually implement it to find out what are some of the advantages and/or disadvantages of any given type of license.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="policiesandBestPracticeGuidelines6InternationalExportControls"></a>
# ***
# ###### 6. International Export Controls
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``describe international export controls``

# %% [markdown]
# In this presentation, we'll take a look at some import and export controls with respect to technology. [Import/Export Controls. ]

# %% [markdown]
# And this deals with the fact that there are federal US regulations in place that do limit the export of computers. And perhaps more specifically, encryption technology.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Now this actually dates back to the Second World War and the German implementation of the Enigma machine. Because of course this represented a method of communication that was unbreakable to the United States and the Allied forces. And while it was eventually broken, they did not want their own encryption technology to find its way out of the country, so that it might possibly be used against them.

# %% [markdown]
# So those regulations actually persisted for quite some time, well into the 1990s in fact.

# %% [markdown]
# But while they were previously strict, they are certainly a lot more relaxed now to encourage open commerce.

# %% [markdown]
# And this is due to the fact that encryption technology has essentially become the cornerstone of e-commerce.

# %% [markdown]
# So again, much more relaxed these days than before. That said, there are still some restrictions.

# %% [markdown]
# So high-performance computing systems these days can be exported to almost every country. But pre-approval by the Department of Commerce is required for Tier 3 countries, and it's entirely still prohibited to Tier 4 countries.

# %% [markdown]
# Now the tiers at a very general level, refer to what kind of adherence to the law is observed in those countries. And the higher your tier, in essence, the more lawless the society. A lot of them deal with human trafficking in fact. So again the idea is we don't want to expose encryption technology and a method for them to secure their communications to use them for criminal activity.

# %% [markdown]
# So again, the Tier 1 and the Tier 2 observe the law much more closely. So, those ones typically do not have any issues with respect to exporting the technology.

# %% [markdown]
# So, if you do have this encryption technology that needs to be exported, [freely ] it can be done, provided you submit that technology to the Department of Commerce for review. And that again goes up to the Tier 3 countries. So if you are an exporter, and you need to export this technology then you do need this review. Otherwise, it would be considered smuggling. So, the review in and of itself should take no longer than 30 days. And you pretty much have to wait for the review to come back, and from that point, you certainly have to adhere to whatever the review says. If they say yes, it's okay, then you can certainly go ahead and export it. If they say no, then clearly you cannot.

# %% [markdown]
# So again, it deals with where it is going, for the most part, and/or where it's coming from, so you always have to be mindful of that. But again, for the most part these days, if you're dealing with typically first world nations, it should not be a problem when it comes to importing and/or exporting this type of technology.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="policiesandBestPracticeGuidelines7DataLossPrevention"></a>
# ***
# ###### 7. Data Loss Prevention (DLP)
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``describe data loss prevention techniques``

# %% [markdown]
# Now in this presentation, we'll take a look at data loss prevention, or as it is commonly referred to as DLP.

# %% [markdown]
# But to quickly clarify, data loss in this context does not refer to the fact that you might have lost a file because you accidentally deleted it or because a hard drive crashed. But rather, it refers to policies and/or restrictions that have been implemented to control how valuable data is used.

# %% [markdown]
# So things such as intellectual property, confidential corporate data, or personally identifiable information needs to be kept within the organization.

# %% [markdown]
# So DLP is, in essence, an approach that is designed to prevent or at least minimize data leakage. So it's this data disclosure outside of the organization that is the essence of data loss. It's not lost because it's gone. It's lost because it found its way into the wrong hands.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Data Loss Prevention (DLP) Risks
# ***

# %% [markdown]
# So some of the risks associated with DLP include malware. And this would probably not really be something like a virus that is designed to destroy the data, but rather, some kind of spyware that is designed to collect it and report it back to whoever is trying to obtain it.

# %% [markdown]
# Social media, people might just post things, maybe even inadvertently, that they shouldn't have, revealing too much information.

# %% [markdown]
# Certainly social engineering and/or phishing scams, people or entities posing as legitimate IT staff, for example, to trick you into revealing your credentials.

# %% [markdown]
# Laptops, tablets, and smartphones, of course the mobile devices, and we'll actually touch on these again shortly. But the problem here is that as you leave the organization, they go with you. So confidential information that is on those devices is much more susceptible to being lost or stolen.

# %% [markdown]
# And, really, the same goes for removable media, such as USB flash drives.

# %% [markdown]
# And in most cases, the risk origin usually goes back to humans. And that simply refers to the fact that people tend to be the weak link. It's not really the technology itself or some sort of attack against the technology, it usually does come back to the people.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Data in Use
# ***

# %% [markdown]
# Now with respect to the data itself, there are effectively three states of data that is in use refers to data that is actually being processed.

# %% [markdown]
# So perhaps, something like a database. So if some kind of rogue application or process finds its way into the database, it could access that data as it's being processed.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Data in Transit
# ***

# %% [markdown]
# Data in transit refers to data being sent or received over a network.

# %% [markdown]
# And, again, anyone who is implementing some sort of packet sniffer could capture that information.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Data at Rest
# ***

# %% [markdown]
# And data at rest means that it is stored on a hard disk or any other permanent type of storage.

# %% [markdown]
# But you have to consider things like hard drives themselves can be stolen from disk arrays or even straight out of a computer.

# %% [markdown]
# And another common approach is backups. Anyone might be able to get their hands on a backup of the data, which might be slightly out of date, but it would still contain the confidential information. So you have to be mindful of how to protect data in all of those states.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Implementing Data Loss Prevention (DLP)
# ***

# %% [markdown]
# [Implementing DLP. ] So then, when it comes to implementing a DLP process, of course you have to identify the valuable data.

# %% [markdown]
# Identify the threats to that data.

# %% [markdown]
# Apply your DLP solution.

# %% [markdown]
# And then, of course, monitor it for effectiveness.

# %% [markdown]
# And that can be difficult, but the more effort you put into it, typically, the better your results will be. And one such example is using something like Microsoft Group Policies in an Active Directory environment to control how removable media [setting. ] is used. And that's up to you. But one example is, in fact, that you can restrict it entirely. You can disallow removable devices so that people cannot copy files onto flash drives.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Mobile Device Data Loss Prevention (DLP)
# ***

# %% [markdown]
# [Mobile Device DLP. ] Now, as mentioned, the mobile devices are a little more challenging.

# %% [markdown]
# But it's not just the fact that they are mobile, these days it is also the fact that they are owned by the users themselves. This is what's referred to as BYOD, or Bring Your Own Device.

# %% [markdown]
# A lot of environments are adopting this because, quite simply, it saves them all the purchasing of those devices. Most people these days already have a tablet or a smartphone. So if you let them use that device, you don't have to purchase a device.

# %% [markdown]
# But now they're using something that is personally owned to access corporate data. So this becomes challenging. Because if you do own it, if the company provides the device, then they can entirely say, here you go, here is the device. But we are going to control how you use that device 100%. You have no say in the matter.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Mobile Device Management (MDM)
# ***

# %% [markdown]
# But with a personal device, they can't really do that, so they have to try to come up with some kind of happy medium.

# %% [markdown]
# And this is typically referred to as mobile device management, or MDM, so that you can centralize how you are going to control these devices.

# %% [markdown]
# So that can include features such as a VPN that's triggered by an app usage, so that when they launch the app that requires them to access corporate data, that is the only thing that triggers the VPN. In other words, they can't just launch it by themselves on their own and keep it connected all day.

# %% [markdown]
# Strong device authentication requirements can be implemented so that they have to ensure that they use a strong pin or a password, for example, and that there is always [Enforced device ] encryption in place for the device itself.

# %% [markdown]
# Device remote wipe, typically, is available as well. So if it is lost or stolen, a command can be issued that wipes it.

# %% [markdown]
# You can control which apps are installed.

# %% [markdown]
# You can disable the Bluetooth and/or the camera to, again, just tighten up the overall security of that device while still allowing them to do their personal tasks.

# %% [markdown]
# You can also implement features such as device partitioning or containerization, which allows you to, effectively, create a division between the corporate data and the personal. So with this, it actually supports a selective wipe. [It includes Corporate partition and Personal partition. Each of them further contains Apps, Settings, and Data. ] Meaning that if it is lost or stolen you can blow away the corporate stuff but still leave the personal, in hopes that, of course, it might be located. Or perhaps, more so, it just might be a case where the person either no longer works for you, or maybe they were just temporary to begin with, or some sort of contractor. So once they are done, you can blow away all of the corporate stuff but leave the personal intact. So, of course, they can just resume using it as they always did.

# %% [markdown]
# Also, you can implement solutions to prevent data from being forwarded, printed, copied and pasted and/or stored in an alternate location. Now this can be done with mobile devices, but in fact, can be extended to standard desktop systems as well. It depends on how you are implementing it, but one example is in an Active Directory environment in Windows, you can implement a service known as Rights Management Service. And this deals with the fact that when it comes to, let's just say, files, you can certainly have permissions that say, well, you are not allowed to access that file. That's all well and good, but if you even have just read access, that prevents you from changing the original. But it absolutely does not prevent you from copying that document, printing it, forwarding it in an email. Taking all the content and pasting it into a new document, and then editing that and disseminating that new copy, or flat out storing it on your own system or on a flash drive or anywhere else. So all of those activities can, in fact, be prevented with something like Rights Management Service.

# %% [markdown]
# So, again, it's up to you to decide how you want to implement these DLP measures. But one way or another, if you are in an environment where there is a lot of confidential information and a lot of ways for that information to leave your organization, then you need to come up with some kind of DLP strategy that will at least reduce the possibility of that data being leaked and, ideally, prevent it altogether.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="policiesandBestPracticeGuidelines8RemoteAccessPolicies"></a>
# ***
# ###### 8. Remote Access Policies
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``deploy remote access policies``

# %% [markdown]
# In this presentation, we'll take a look at remote access, but not really from a technical perspective.

# %% [markdown]
# But rather one of implementing some sort of policy and/or controlling how remote access is used.

# %% [markdown]
# [Remote Access. ] Because of course these days it's very common for people to work from home, or to travel. So remote access, [is a technology ] in and of itself, certainly allows us to connect into an organization's local area network. [remotely ] But, you also then need to generally define some kind of remote access policy, which outlines acceptable methods for allowing these remote connections into your LAN. And then of course what people can do with that ability.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Purpose
# ***

# %% [markdown]
# [Purpose. ] So you generally need to define the purpose of the policy.

# %% [markdown]
# For example, you want to try to minimize the potential exposure to unauthorized use of company resources.

# %% [markdown]
# Things such as confidential data, intellectual property and of course just the access to your internal systems needs to be controlled. So that not just anyone can establish a remote connection and then do whatever they want. We obviously need to implement the same kind of restrictions that you would within the internal environment for these external users as well.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Scope
# ***

# %% [markdown]
# [Scope. ] So when it comes then to the scope, you also need to determine, well, who is going to be affected by this policy?

# %% [markdown]
# And of course this would include your own employees but might also include vendors, or other business partners, or suppliers. Any kind of agent who represents someone else, perhaps temporary contractors. Really just about anyone that might need to gain access.

# %% [markdown]
# But then you also have to try to determine, well, what kind of device is allowed to connect? And generally if it's a work issued then you can really control it, but if it's a personal device then it becomes a little more difficult. And this is what we discussed earlier, the BYOD, bring your own device type of scenario. Wherein someone says, well, I already have my own personal tablet or smartphone, can't I just use that? Well, I mean, they can, but that's up to you. And it generally comes down to how much you can control that device, in terms of its security profile. So again, generally there would be a little less restriction implemented on a work issued device because they can control it. But a personal device would be much more restricted.

# %% [markdown]
# You also have to try to determine which tasks can a connected user perform. And again, this is entirely your call as administrator. But the things that they commonly need to do include accessing e-mail, [systems. ] accessing an intranet website or any kind of internal resource of the environment. So again, based on who they are and what they're using, you can kind of base your decision on that. Again, internal employees using work-issued devices would probably have a little more freedom, if you will, than a temporary contractor using a personal device. There are always considerations.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Policy
# ***

# %% [markdown]
# [Policy. ] So the policy should outline the responsibilities of users with remote access privileges. And the idea is to ensure that external connections are given the same privileges as internal connections.

# %% [markdown]
# In other words, if I am an internal employee and I do most of my work within the environment, but then I do need casual access when I'm traveling or working from home. Then I really should still be able to do all of the same things. Now, again that really is up to you. You can still say, well, no, those external connections aren't as secure, therefore we are going to restrict you. But it always depends on what the user needs to do. If they legitimately need to gain access to resource x, whatever that is, then they usually should still be able to access it no matter where they are.

# %% [markdown]
# But users are then responsible for preventing any unauthorized access to the company resources once connected. And of course any illegal activities on the network are certainly prohibited and should be outlined in an acceptable use policy.

# %% [markdown]
# But when it comes to that responsibility, users need to be aware. If they do make a connection, let's say over a VPN, from something like a hotel that might have unsecured wireless access. Well, they are exposing that data to potential compromise because of course it's traveling between their computer and the wireless access point in an unencrypted fashion. So, they need to be aware of those types of things. Or if, another example, maybe they're just at a coffee shop and they're working away and they get up to go get a coffee. And they leave their computer connected with confidential information up on the screen. That basically has to be addressed. They need to know that they are responsible for that data once they make that connection.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Compliance
# ***

# %% [markdown]
# [Compliance. ] Compliance, of course, this is something that can be measured, and typically on an on-going basis.

# %% [markdown]
# So you can implement things such as audits and reporting tools to quite literally see that user x connected at this point in time, from here, for this long, performed these actions, and so on. So you can review those to find out if your policies are being effective.

# %% [markdown]
# And in some cases there might be exceptions and this is fine. But they typically have to be approved by a network security team. So again, maybe you are going to be traveling and you know that there is no secured wireless access. A security team would evaluate that and say, well no, that's not acceptable, you cannot make the connection over an unsecured wireless network. So again, there might be situations where something is acceptable but it would be dependent on certain criteria being met.

# %% [markdown]
# And any kind of noncompliance, of course, deals with violations. And as such there can be disciplinary action that might go along with that.

# %% [markdown]
# So if you did make that connection over an unsecured wireless LAN when the security team said, no, you should not. Then of course, you were not in compliance with the policy, and you should typically expect some kind of action to be taken.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Related Policies
# ***

# %% [markdown]
# [Related Policies. ] And other standards, policies and processes may be implemented in some way, shape, or form, including an acceptable use policy and acceptable encryption policy.

# %% [markdown]
# A password policy that has to be enforced.

# %% [markdown]
# Maybe some kind of third-party agreement and/or hardware and software configuration standards. So that again, you cannot establish this connection unless you are using a device that has been deemed acceptable and with a software configuration that is acceptable. Which typically includes things like there has to be an anti-virus program. There needs to be a firewall, there needs to be the latest service pack, things along those lines.

# %% [markdown]
# So, again from the perspective of administration it is really all up to them. But there are a lot of things that they need to take into consideration when it comes to remote access. And then you as the user need to be aware of all those restrictions to ensure that you understand why the policy's in place and what it is designed to do.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="policiesandBestPracticeGuidelines9IncidentResponsePolicies"></a>
# ***
# ###### 9. Incident Response Policies
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``deploy incident response policies``

# %% [markdown]
# Now in this presentation we'll take a look at an incident response policy, which is a guide developed in the event that a security incident occurs on the network.

# %% [markdown]
# And depending on the organization, the policy generally applies to your own employees of course whether they are internal or external.

# %% [markdown]
# Any vendors, any independent consultants or contractors, any agents, really anyone with whom you do business.

# %% [markdown]
# They would all be generally covered by some kind of incident response policy.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Purpose
# ***

# %% [markdown]
# [Purpose. ] And the purpose of course is to mitigate any effects caused by an incident and ideally to remove that threat.

# %% [markdown]
# You also want to protect the information and the resources of your organization against unauthorized use, damage, or theft.

# %% [markdown]
# And to ensure a formal process is carried out to record the impact of the incident as well as any actions that were performed to rectify the incident.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Definitions
# ***

# %% [markdown]
# [Definitions. ] Now, with respect to some terminology.

# %% [markdown]
# When you are defining this type of report, [in the incident response guideline. ] it's not uncommon to see terms such as computer systems, prohibited information, restricted information. Security incident, specifically with respect to unauthorized use. Unwanted disruption or theft.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Notifications
# ***

# %% [markdown]
# [Notifications. ] And notifications are actions that are taken upon becoming aware of a security incident or a threat.

# %% [markdown]
# Of course, there should always be someone to inform.

# %% [markdown]
# So you want to identify and disconnect any compromised system from the network, and essentially isolate that system until an investigation has been completed.

# %% [markdown]
# And generally it's a good idea to just leave that system alone.

# %% [markdown]
# Avoid implementing any updates or software modifications. Basically leave it as it was, and of course contact whoever the appropriate responder is, for example, the network security team.

# %% [markdown]
# So in other words if you are the one who has discovered it, but you are not the necessarily the security person, then basically take these steps to try to keep everything exactly as it is.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Containment
# ***

# %% [markdown]
# [Investigation. ] So containment again, really is step one of an investigation. And you are effectively just ensuring that unauthorized access is prevented from that point on. So this often requires disconnecting it from the network and this generally means at a physical level, entirely disconnect the cables. Possibly shut the computer down. But you might not want to do that, because there may be information that is still retained in temporary files or even in the memory that could be important. So it's generally recommended to leave it on, but disconnected from the network. Because of course, nothing can spread from that system, if it was something like a virus or malware, if it's disconnected from the network and of course, if it's an attempt to intrude into the system. The most skilled hacker in the world is not going to be able to connect to a system that has its cable physically unplugged.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Investigation
# ***

# %% [markdown]
# So then investigation of course involves determining who or what caused the incident, when it occurred.

# %% [markdown]
# Typically a classification of the information on a compromised system. In other words, was it restricted information? And what is the impact of that unauthorized activity? How severe is this breach?

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Incident Response Team
# ***

# %% [markdown]
# [Incident Response Team. ] And then there is generally an incident response team that is defined.

# %% [markdown]
# And they are of course responsible for developing an appropriate incident response plan.

# %% [markdown]
# They're tasked with ensuring that a response is initiated in a timely manner, and that there is reporting and notification about the incident.

# %% [markdown]
# To ensure that the progress is communicated to the stakeholders, the management, and possibly the victim of the attack as well.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Reporting
# ***

# %% [markdown]
# [Reporting. ] And reporting is certainly a key component. You should document the findings in a final report that outlines what the incident was and what kind of ensuing investigation took place.

# %% [markdown]
# And it should summarize findings and any actions taken by the responders to contain the threat.

# %% [markdown]
# And then finally recommendations should be outlined in the event of future incidents. So, based on what we have learned from this incident, what can we do in the future to prevent it from happening again or at least preventing a similar incident?

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Related Policies
# ***

# %% [markdown]
# [Related Policies. ] And there may be other related policies that are referenced as part of the investigation as well. Some other standards, some other policies and procedures, and various processes that may just come out again in many cases just as reminders.

# %% [markdown]
# So things like the acceptable use policy, the acceptable encryption policy. Overall computer and network usage policy, password policy, third party agreements such as service level agreements.

# %% [markdown]
# And hardware and software configuration standards. Because maybe it was identified that the breach was because of something that was not observed in these standard policies. So they might present that as a reminder, if you will, to say remember to do this. And that should typically help to avoid this problem from arising again in the future.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="policiesandBestPracticeGuidelines10BYODAUPandNDA"></a>
# ***
# ###### 10. BYOD, AUP, and NDA
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``describe appropriate situations to use BYOD, AUP, and NDA``

# %% [markdown]
# In this presentation, we will take a look at three different implementations of best practices and/or security policy implementation, beginning with BYOD, or bring your own device.

# %% [markdown]
# And then we'll also see the acceptable usage policy.

# %% [markdown]
# And then finally the non-disclosure agreement.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### BOYD
# ***

# %% [markdown]
# [BYOD. ] Now, these are becoming a little more common these days, particularly when it comes to dealing with external employees, or outside contractors, or temporary employees, or things along those lines.

# %% [markdown]
# Now, that's not at all to suggest that you only see these things in those cases. It's just that it's becoming a little more common these days to deal with contractors, temporary workers, there are fewer full time employees.

# %% [markdown]
# And in essence, you want to ensure that when you are dealing with someone who maybe is not an internal employee, that things are a little more clearly defined and in essence a little more controlled.

# %% [markdown]
# Now again, that's not at all to suggest that you don't see these with full time employees. They're just becoming more common as things tend to spread out beyond the internal organization.

# %% [markdown]
# So, BYOD again, is Bring Your Own Device. Very common with contractors and temporary employees because, you don't necessarily want to have to provide them with a device if they are only going to be around for a short term contract. So in essence, you let them use their own device.

# %% [markdown]
# But there obviously are concerns with that because it is their device, you don't control it. So you don't really know it's security configuration, and of course that can present a challenge. And if you go back, let's say maybe 10 or 15 years, this was very rare because of the fact that administration could not control that device. In most cases they would just say no, you can't use your own device at all. We don't control it, that's it.

# %% [markdown]
# So, it is becoming a little more relaxed because of the fact that there are ways to deal with these devices now.

# %% [markdown]
# But the overall essence of the approach, is to let these employees or contractors use their own devices within the business environment, including smartphones, tablets, laptops or any kind of USB drives.

# %% [markdown]
# But when it comes to the restrictions that you want to implement, you can define acceptable use. Now, we'll talk about that as a policy in a moment, but specifically, with respect to the BYOD environment, you generally define. Here is what you can do with this device. Send and receive email, access calendar, access documents. But it's much more controllable these days.

# %% [markdown]
# There are means to implement control over these devices, and they typically support the standard types that are in use today.

# %% [markdown]
# The iOS devices, iPhones and iPads, Blackberry, Windows devices of course, and Android. They are all configurable and controllable with various types of applications.

# %% [markdown]
# In a Microsoft environment, mobile device management is typically implemented, maybe with System Center Configuration Manager and/or Intune.

# %% [markdown]
# But again, there are other applications that can do the same thing. So once you have implemented a BYOD policy and defined what the acceptable use is, you can now control the security. And again, this is really what was never available before. You can implement a password policy and require things like strong passwords. You can require PIN locks. You can prevent rooted or jail broken devices from being used. And if you need to, you can remotely wipe the device, if it's lost or stolen, or if the employee is terminated. Or if some kind of breach has been detected. [such as Policy breach. ] And in some cases you can partition the phone, if you will, so that there is still all of their personal stuff but then there's their corporate stuff that's separate. And you can wipe just the corporate stuff if necessary.

# %% [markdown]
# So again, by enrolling these devices into the appropriate mobile device management application, administration now has this level of control that was never there before.

# %% [markdown]
# So again, BYOD certainly becoming more common, and as mentioned, definitely used in the independent contractor type of scenario, but still for internal employees as well.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Acceptable Usage Poilcy (AUP)
# ***

# %% [markdown]
# [AUP. ] Now an AUP, or an acceptable use or usage policy, simply documents the best practices, the constraints, and the expectations that users must agree to. Prior to accessing a network, and not just from a BYOD type of scenario.

# %% [markdown]
# This is for all access within the corporate network or even accessing the internet or accessing the corporate network from the internet.

# %% [markdown]
# And this is commonly used in universities, or really any kind of business, really just anywhere that needs to control behavior of those who are in the environment.

# %% [markdown]
# Stipulations generally include of course, do not violate the law. Do not attempt to breach security with respect to the computer or a user.

# %% [markdown]
# Junk mail and or spam. No spamming other users who do not want to receive it.

# %% [markdown]
# You have to respect copyrights and intellectual property and of course, you are expected to not distribute malware or viruses. Now clearly, they would seem to be fairly obvious. But it's not just a matter of outlining what is expected, but of course what the consequences might be. So, those should be outlined in the policy. And it's going to vary. Of course depending on what the violation was, and how severe it was. But can certainly result in termination of the user's access to the network or maybe restriction, with respect to their access. And they may have to disclose the incident to law enforcement authorities, of course if anything illegal did take place. And clearly, it might also result in, termination of your employment.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Non-Disclosure Agreement
# ***

# %% [markdown]
# [NDA. ] And finally, the NDA or non-disclosure agreement, this is often referred to as a confidentiality agreement as well. And it's just a legally binding contract between two parties, where by one party agrees to give confidential information to another party. And the other party agrees not to reveal that information to anyone outside of the organization. And again, the idea is to protect that confidential information such as trade secrets, proprietary information and or legal contracts. And again, violations can result in very strict penalties. And that would need to be outlined in the NDA, but in essence once you sign that, you are agreeing to protect that information and failure to do so, can result in some fairly significant consequences. Possibly both legally and just within the organization itself.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="policiesandBestPracticeGuidelines11SystemLifeCycle"></a>
# ***
# ###### 11. System Life Cycle
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``describe best practices for system life cycles such as asset disposal``

# %% [markdown]
# Our next implementation of policies and procedures and/or best practices is the system life cycle.

# %% [markdown]
# And this is concerned with identifying, analyzing, and assessing the needs of the organization.

# %% [markdown]
# Things change on an ongoing basis, and you need to keep up essentially. So this is particularly common when planning. And that can be your budgets, procurement time, refresh timelines, allocation of resources, current inventory and the disposal of what you have.

# %% [markdown]
# So it's always just that things come in and things go out.

# %% [markdown]
# That never ending cycle of how you keep current, really, is what it's all about.

# %% [markdown]
# So with respect to budgeting, you certainly have to bear in mind what are the computing needs of the environment, particularly when it comes to hardware and software.

# %% [markdown]
# Obviously hardware becomes out-of-date, new software is released.

# %% [markdown]
# So, you need to know what are we going to do with respect to keeping current? So typically this involves requesting new purchases. And that can involve submitting a proposal, which is then evaluated and in many cases prioritized. So you can say we need this first, then this, then this. These are more important than those. And then there is usually some sort of allocation plan, which is determined based on the needs and the budget assessment. But the plan should be approved by the stakeholders and the management.

# %% [markdown]
# And procurement of course is then initiated upon approval of the budget.

# %% [markdown]
# And technology requests should be approved at that point. So this is, in essence, the powers that be saying, okay, this has been approved, so begin your purchasing.

# %% [markdown]
# And you generally need to outline what kind of refresh period there is. So again, you have to review and prioritize new requests. In most cases, you don't just get rid of everything all at once and replace it all at once, it's an ongoing cycle. So as items become dated, the performance may certainly decrease. The hardware may not be up to speed with the new software that you have implemented or vice versa. Maybe the hardware is perfectly fine, but the software is becoming quite dated.

# %% [markdown]
# So you always again need to be mindful of what that refresh cycle is, how often do these new purchases have to be made.

# %% [markdown]
# And you'll also have to consider disposal, implementing proper disposal practices and/or recycling. But that is actually something that needs to be very carefully monitored with respect to the privacy of the organization. If for example you are just donating old computers, in almost every case you would never include the hard drive with those systems, just in case there is any confidential information on them. So, the hard drives themselves are almost never recycled. They're usually very thoroughly destroyed. This is a process you might have heard of, known as shredding.

# %% [markdown]
# And it involves completely demagnetizing the disks several times over. Writing random passes of all ones, all zeros. Then a bunch of different passes of ones and zeros to ensure that everything is overwritten. Then they are typically de-magnetized and physically destroyed.

# %% [markdown]
# So again in a higher security environments, they definitely take significant steps to ensure that data itself is never given away or even just disposed of without these measures being taken.

# %% [markdown]
# So, it's certainly something to bear in mind, depending on the security of your environment.

# %% [markdown]
# But that's something that should be outline in other documentation. But something you should definitely ensure you are aware of when it comes to disposal and implementing sort of that final phase of the system life cycle.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="policiesandBestPracticeGuidelines12SafetyProceduresandPolicies"></a>
# ***
# ###### 12. Safety Procedures and Policies
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``recall safety procedures and policies``

# %% [markdown]
# Now, in our final presentation of this course, we'll take a look at some safety procedures and policies, and also how data is collected and used.

# %% [markdown]
# Now, with respect to the safety and policies concerned with safety, at least in this presentation, we're not really talking about physical safety, but rather the safety of your information.

# %% [markdown]
# Organizations have legal obligations that require information to be protected and secured. Particularly, in environments such as banking, health, political, and law enforcement. If they are going to gather information about you and store that information, then you want to be assured that it is done so in a safe manner.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Privacy Policy
# ***

# %% [markdown]
# So in essence, these organizations need to define a privacy policy.

# %% [markdown]
# And this outlines how a business collects and stores information.

# %% [markdown]
# They have to inform you where the information is stored, and in what manner. And in essence, the steps that are taken to ensure that it is stored securely.

# %% [markdown]
# Not only do they then need to inform you how it is stored, but also how they will use it, and whether or not that information can be shared with any third parties. And if so, what kind of restrictions are in place.

# %% [markdown]
# Now, in some cases, it's perfectly fine for them to share that information, but they have to make that known to you. For example, banking information. Many banks might deal with an investment company, or an insurance company, or a credit card company. And they may, quite legitimately, share your information with them, because they have this business partnership. But again, they need to inform you about that. And perhaps more to the point, they also need to inform you how they will not share it. In other words, they clearly define, this information will not be distributed to so and so and so, and so and so.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Procedures
# ***

# %% [markdown]
# [Procedures. ] Now procedures should be defined for those accessing and using any corporate IT systems.

# %% [markdown]
# And they should also outline any expectations for those accessing the network resources, both internally and externally. Who is able to access my personal information? I need to know that, as a customer.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Risk Management
# ***

# %% [markdown]
# [Risk Management. ] Risk management should also be outlined.

# %% [markdown]
# There should be a plan that indicates the use of SSL certificates and firewalls, the password policies, and how they deal with antivirus and/or malware. And essentially, it should identify and manage any and all risks to data, systems and, of course, the users who are accessing that information.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Business Continuity Plan
# ***

# %% [markdown]
# [Business Continuity Plan. ] And finally, a business continuity plan should also be outlined.

# %% [markdown]
# And this can help to minimize damage, interruption or loss of any kind of data or service.

# %% [markdown]
# And it should identify the critical business functions, the equipment, and the data that is implemented, to help ensure that services are able to continue.

# %% [markdown]
# Now, again, it's basically just something that they need to present to you, as a customer, that says here is how we handle things.

# %% [markdown]
# Here is how we implement our security. Here's how we implement our risk management, here's how we implement business continuity.

# %% [markdown]
# From that point, it's up to you to decide if that is acceptable before you start doing business with them.

# %% [markdown]
# But typically, for any kind of reputable company that does store this very sensitive information, they should have this all outlined. And in most cases, it absolutely is. It's usually on their website, if I'm a customer. And then also, if I'm an employee of that organization, I need to be aware of those as well. So that would be internal documentation.

# %% [markdown]
# But it effectively needs to be very well known, and very well understood, by both sides, the internal employees and the customers with whom they are dealing. So everybody has a good understanding of, effectively, how things happen in this environment.

# %% [markdown]
# So again, from the customer's perspective, it's certainly your call. But you need to ensure that something is outlined, so that you have some kind of recourse if something does go wrong.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="policiesandBestPracticeGuidelinespractice"></a>
# ***
# ### Practice: Incorporate Best Practice Guidelines
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``incorporate best practice guidelines``
#
# i. Describe the purpose of a privileged user agreement.
#
#
# ii. Then to describe onboarding and offboarding best practices.
#
#
# iii. Then to describe the risks associated with data loss prevention.
#
#
# iv. And finally, to describe some of the settings associated with a password policy.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="policiesandBestPracticeGuidelinesexercise"></a>
# ***
# ###### 1. Exercise: Incorporate Best Practice Guidelines
# ***

# %% [markdown]
# i. Describe the purpose of a privileged user agreement.

# %% [markdown]
# And essentially this is to define those users with elevated privileges and to outline what is expected of them, in terms of exercising those abilities. In short network administrators, system administrators. Users who are in many cases unrestricted with respect to accessing the resources, of any given environment. And controlling those who also need to access. So it really is just an understanding that says, here is what you are expected to do with respect to those responsibilities so that everybody understands.

# %% [markdown]
# ii. Then we asked to describe onboarding and offboarding best practices.

# %% [markdown]
# And this is to ensure easy and efficient transitions of employees in or out of an organization. And of course, onboarding is the new employee coming in so new hires. And offboarding, is as an employee leaves or possibly just moves to a different division, or department. But again, it is to outline quite simply here is how things work. So that users can be as comfortable and familiar with the environment as possible when coming on board. And again ensuring that all the loose ends are tied up as they leave the environment. So again, the more that can be clearly defined the easier those transitions will be.

# %% [markdown]
# iii. Then we asked to describe the risks associated with data loss prevention.

# %% [markdown]
# These include malware, social media, social engineering or phishing scams, mobile devices which of course are very easily lost or stolen. And really the same goes for removable media, and of course human error. So again really, education and awareness is one of the best tools with respect to data loss prevention.

# %% [markdown]
# iv. And finally, we asked to describe some of the settings associated with a password policy.

# %% [markdown]
# And these include the history, how many times a user has to use a different passwords before they can go back to the original one.

# %% [markdown]
# The maximum and/or the minimum age. Maximum is the expiry time. They must change it after x number of days. Minimum means they must use it for at least a certain number of days before they can voluntarily change it. Because you don't have to use the same password for the entire duration of the expiry period. You can change it earlier if you want to.

# %% [markdown]
# The length is quite simply how many characters. The longer the password the more difficult it is to guess.

# %% [markdown]
# Complexity typically involves the use of mixing the case of the characters, using a combination of letters and numbers or symbols. And essentially having a higher number of characters. Typically, as long as you meet three out of four characteristics plus avoiding things like your username itself in the password, then you will generally satisfy complexity requirements. But you don't want to go too crazy with complexity, because if it's too difficult to remember, then this can backfire and users will start writing down the passwords. That in and of itself isn't all that bad, as long as they keep the written down copy safe. But, they tend to show up on sticky notes under the keyboard or on the monitor.

# %% [markdown]
# And also reversible encryption which you may see in backward compatibility environments. Older applications may need a password that is not encrypted. This is certainly not recommended. But again, for some older applications, it might be required but this is disabled by default.

# %% [markdown]
# So ultimately it is up to administration to determine what the password policy is going to look like. But it should try to strike the balance between being secure while not being so difficult that you end up shooting yourself in the foot, if you will, with those written down passwords.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="policiesandBestPracticeGuidelinesTest"></a>
# ***
# ### ⚡ Test
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="references"></a>
# ***
# ## References
# ***

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="appendix"></a>
# ***
# ## Appendix
# ***

# %% [markdown]
# ***
# ## END

# %%
from IPython.core.display import display,HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # END JUPYTER NOTEBOOK
